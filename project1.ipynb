# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
cir=pd.read_csv("cirrhosis.csv")

# %%
cir
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
cir.head()
# Out:
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
cir['Stage'].unique()
# Out:
# array([ 4.,  3.,  2.,  1., nan])

# %%
cir.tail()
# Out:
#       ID  N_Days Status Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# 413  414     681      D  NaN  24472   F     NaN          NaN     NaN     N
# 414  415    1103      C  NaN  14245   F     NaN          NaN     NaN     N
# 415  416    1055      C  NaN  20819   F     NaN          NaN     NaN     N
# 416  417     691      C  NaN  21185   F     NaN          NaN     NaN     N
# 417  418     976      C  NaN  19358   F     NaN          NaN     NaN     N
#
#      Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos  SGOT  Tryglicerides  \
# 413        1.2          NaN     2.96     NaN       NaN   NaN            NaN
# 414        0.9          NaN     3.83     NaN       NaN   NaN            NaN
# 415        1.6          NaN     3.42     NaN       NaN   NaN            NaN
# 416        0.8          NaN     3.75     NaN       NaN   NaN            NaN
# 417        0.7          NaN     3.29     NaN       NaN   NaN            NaN
#
#      Platelets  Prothrombin  Stage
# ...

# %%
cir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             418 non-null    int64
#  1   N_Days         418 non-null    int64
#  2   Status         418 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            418 non-null    int64
#  5   Sex            418 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          418 non-null    object
#  10  Bilirubin      418 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        418 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
# ...

# %%
cir.describe(include='all')
# Out:
#                 ID       N_Days Status             Drug           Age  Sex  \
# count   418.000000   418.000000    418              312    418.000000  418
# unique         NaN          NaN      3                2           NaN    2
# top            NaN          NaN      C  D-penicillamine           NaN    F
# freq           NaN          NaN    232              158           NaN  374
# mean    209.500000  1917.782297    NaN              NaN  18533.351675  NaN
# std     120.810458  1104.672992    NaN              NaN   3815.845055  NaN
# min       1.000000    41.000000    NaN              NaN   9598.000000  NaN
# 25%     105.250000  1092.750000    NaN              NaN  15644.500000  NaN
# 50%     209.500000  1730.000000    NaN              NaN  18628.000000  NaN
# 75%     313.750000  2613.500000    NaN              NaN  21272.500000  NaN
# max     418.000000  4795.000000    NaN              NaN  28650.000000  NaN
#
# ...

# %%
cir.isnull().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
cir.columns=cir.columns.str.lower()

# %%
number_columns=cir.select_dtypes(include=['int64','float64']).columns
for columns in number_columns:
    cir[columns].fillna(cir[columns].median(), inplace=True)

# %%
cir.isnull().sum()
# Out:
# id                 0
# n_days             0
# status             0
# drug             106
# age                0
# sex                0
# ascites          106
# hepatomegaly     106
# spiders          106
# edema              0
# bilirubin          0
# cholesterol        0
# albumin            0
# copper             0
# alk_phos           0
# sgot               0
# tryglicerides      0
# platelets          0
# prothrombin        0
# stage              0
# dtype: int64

# %%
category_columns=cir.select_dtypes(include=['object']).columns
for columns in category_columns:
    cir[columns].fillna(cir[columns].mode()[0],inplace=True)

# %%
cir.isnull().sum()
# Out:
# id               0
# n_days           0
# status           0
# drug             0
# age              0
# sex              0
# ascites          0
# hepatomegaly     0
# spiders          0
# edema            0
# bilirubin        0
# cholesterol      0
# albumin          0
# copper           0
# alk_phos         0
# sgot             0
# tryglicerides    0
# platelets        0
# prothrombin      0
# stage            0
# dtype: int64

# %%
cir['age_years']=cir['age']/365

# %%
cir=cir.drop(columns={'id','age'})

# %%
cir['drug'].value_counts()
# Out:
# drug
# D-penicillamine    264
# Placebo            154
# Name: count, dtype: int64

# %%
cir['status'].value_counts()
# Out:
# status
# C     232
# D     161
# CL     25
# Name: count, dtype: int64

# %%
cir['sex'].value_counts()
# Out:
# sex
# F    374
# M     44
# Name: count, dtype: int64

# %%
cir['stage'].value_counts().sort_index()
# Out:
# stage
# 1.0     21
# 2.0     92
# 3.0    161
# 4.0    144
# Name: count, dtype: int64

# %%
pd.crosstab(cir['sex'],cir['status'])
# Out:
# status    C  CL    D
# sex
# F       215  22  137
# M        17   3   24

# %%
cir['ascites'].value_counts().sort_index()
# Out:
# ascites
# N    394
# Y     24
# Name: count, dtype: int64

# %%
cir['hepatomegaly'].value_counts().sort_index()
# Out:
# hepatomegaly
# N    152
# Y    266
# Name: count, dtype: int64

# %%
cir
# Out:
#      n_days status             drug sex ascites hepatomegaly spiders edema  \
# 0       400      D  D-penicillamine   F       Y            Y       Y     Y
# 1      4500      C  D-penicillamine   F       N            Y       Y     N
# 2      1012      D  D-penicillamine   M       N            N       N     S
# 3      1925      D  D-penicillamine   F       N            Y       Y     S
# 4      1504     CL          Placebo   F       N            Y       Y     N
# ..      ...    ...              ...  ..     ...          ...     ...   ...
# 413     681      D  D-penicillamine   F       N            Y       N     N
# 414    1103      C  D-penicillamine   F       N            Y       N     N
# 415    1055      C  D-penicillamine   F       N            Y       N     N
# 416     691      C  D-penicillamine   F       N            Y       N     N
# 417     976      C  D-penicillamine   F       N            Y       N     N
#
# ...

# %%
cir['age_years'].hist(bins=15)
plt.show()

# %%
cir.boxplot(figsize=(10,10))
plt.show()

# %%
cir.hist(figsize=(15,15),xrot=30,bins=20)
plt.show()

# %%
sns.countplot(x='sex',hue='drug',data=cir)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
cir.plot.scatter(x='age_years',y='n_days')
sns.regplot(x='age_years',y='n_days',data=cir)
# Out:
# <Axes: xlabel='age_years', ylabel='n_days'>

# %%
sns.barplot(x='sex',y='drug',hue='stage',palette='rocket',data=cir)
# Out:
# <Axes: xlabel='sex', ylabel='drug'>

# %%
sns.barplot(x='status',y='age_years',hue='drug',palette='husl',data=cir)
# Out:
# <Axes: xlabel='status', ylabel='age_years'>

# %%
cols=['bilirubin','cholesterol','albumin','copper','alk_phos','sgot', 'tryglicerides', 'platelets', 'prothrombin']
plt.figure(figsize=(12,10))
for i,col in enumerate(cols,1):
    plt.subplot(3,3,i)
    sns.countplot(x=col,hue='status',data=cir)
plt.tight_layout()
plt.show()

# %%
cols=['ascites','hepatomegaly','spiders','edema']
for i,col in enumerate(cols,1):
    plt.subplot(2,2,i)
    sns.countplot(x=col,hue='status',data=cir)
plt.tight_layout()
plt.show()

# %%
num_cols=cir.select_dtypes(include='number').columns
for col in num_cols:
    q1=cir[col].quantile(0.25)
    q3=cir[col].quantile(0.75)
    iqr=q3-q1
    lower=q1-1.5*iqr
    upper=q3+1.5*iqr
    cir[col]=np.clip(cir[col],lower,upper)

# %%
cir[num_cols].plot(kind='box',subplots=True,layout=(4, 3),figsize=(15, 12))
plt.tight_layout()
plt.show()

# %% [markdown]
# encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_cols=cir.select_dtypes(include='object').columns
le=LabelEncoder()
for col in cat_cols:
    cir[col]=le.fit_transform(cir[col])

# %%
cir
# Out:
#      n_days  status  drug  sex  ascites  hepatomegaly  spiders  edema  \
# 0       400       2     0    0        1             1        1      2
# 1      4500       0     0    0        0             1        1      0
# 2      1012       2     0    1        0             0        0      1
# 3      1925       2     0    0        0             1        1      1
# 4      1504       1     1    0        0             1        1      0
# ..      ...     ...   ...  ...      ...           ...      ...    ...
# 413     681       2     0    0        0             1        0      0
# 414    1103       0     0    0        0             1        0      0
# 415    1055       0     0    0        0             1        0      0
# 416     691       0     0    0        0             1        0      0
# 417     976       0     0    0        0             1        0      0
#
#      bilirubin  cholesterol  albumin  copper  alk_phos    sgot  tryglicerides  \
# ...

# %%
cir.shape
# Out:
# (418, 19)

# %% [markdown]
# ml

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.tree import plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier

# %%
y=cir.status
x=cir.drop('status',axis=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)

# %% [markdown]
# decision tree

# %%
dr_model=DecisionTreeClassifier(random_state=46,criterion='gini',max_depth=5,max_features='sqrt',min_samples_leaf=1,min_samples_split=10)
dr_model.fit(x_train,y_train)
y_pred=dr_model.predict(x_test)
print('accuracy=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuracy= 0.753968253968254
#               precision    recall  f1-score   support
#
#            0       0.70      0.94      0.81        66
#            1       0.67      0.29      0.40         7
#            2       0.89      0.58      0.70        53
#
#     accuracy                           0.75       126
#    macro avg       0.75      0.60      0.64       126
# weighted avg       0.78      0.75      0.74       126

# %% [markdown]
# HYPERPARAMETER TUNING FOR DECISIONTREE

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 10, 15, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2']
}
grid_dt = GridSearchCV(
    DecisionTreeClassifier(random_state=46,criterion='entropy',max_depth=3,max_features='sqrt',min_samples_leaf=1,min_samples_split=2),
    param_grid,
    cv=5,
    scoring='accuracy'
)
grid_dt.fit(x_train, y_train)
best_dt = grid_dt.best_estimator_

y_pred_dt = best_dt.predict(x_test)

print(grid_dt.best_params_)
print("Accuracy =", accuracy_score(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))
# Out:
# {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy = 0.7142857142857143
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77        66
#            1       0.00      0.00      0.00         7
#            2       0.71      0.74      0.72        53
#
#     accuracy                           0.71       126
#    macro avg       0.49      0.50      0.50       126
# weighted avg       0.70      0.71      0.71       126

# %%
cm_dr=confusion_matrix(y_test,y_pred)
sns.heatmap(cm_dr,annot=True,fmt='d')
plt.show()

# %%
best_dr = dr_model#grid_dt.best_estimator_
scores = cross_val_score(
    best_dr,
    x,
    y,
    cv=5,
    scoring='accuracy'
)
print("Scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Scores: [0.66666667 0.64285714 0.5952381  0.6626506  0.6746988 ]
# Mean Accuracy: 0.6484222604704531

# %% [markdown]
# randomforestclassifier

# %%
rf_model=RandomForestClassifier(n_estimators=11,random_state=30,min_samples_split=9,max_depth=13)
rf_model.fit(x_train,y_train)
y_pred_model=rf_model.predict(x_test)
print('accuracy=',accuracy_score(y_test,y_pred_model))
print(classification_report(y_test,y_pred_model))
# Out:
# accuracy= 0.7936507936507936
#               precision    recall  f1-score   support
#
#            0       0.76      0.94      0.84        66
#            1       0.00      0.00      0.00         7
#            2       0.86      0.72      0.78        53
#
#     accuracy                           0.79       126
#    macro avg       0.54      0.55      0.54       126
# weighted avg       0.76      0.79      0.77       126
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
rfc = RandomForestClassifier(n_estimators=11,random_state=30,min_samples_split=9,max_depth=13)
params = {
    'max_depth':[5,10,15],
    'criterion':['gini','entropy'],
    'min_samples_split': [2, 5, 10]
}
grid_rf = GridSearchCV(
    estimator=rfc,
    param_grid=params,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2
)
grid_rf.fit(x_train, y_train)
y_pred_model=grid_rf.predict(x_test)
print('accuracy=',accuracy_score(y_test,y_pred_model))
print(classification_report(y_test,y_pred_model))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# accuracy= 0.7380952380952381
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79        66
#            1       0.00      0.00      0.00         7
#            2       0.78      0.66      0.71        53
#
#     accuracy                           0.74       126
#    macro avg       0.50      0.51      0.50       126
# weighted avg       0.70      0.74      0.71       126
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
cm = confusion_matrix(y_test, y_pred_model)
print(cm)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)
plt.show()
# Out:
# [[58  0  8]
#  [ 5  0  2]
#  [18  0 35]]

# %%
best_rf = rf_model#grid_rf.best_estimator_
scores = cross_val_score(
    best_rf,
    x,
    y,
    cv=5,
    scoring='accuracy'
)
print("Scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Scores: [0.69047619 0.78571429 0.76190476 0.69879518 0.6746988 ]
# Mean Accuracy: 0.7223178427997705

# %% [markdown]
# logisticregression

# %%
model_lr=LogisticRegression(max_iter=200,random_state=46,C=0.1,penalty='l2',solver='lbfgs')
model_lr.fit(x_train,y_train)
y_pred_lr=model_lr.predict(x_test)
print('accuracy=',accuracy_score(y_test,y_pred_lr))
print(classification_report(y_test,y_pred_lr))
# Out:
# accuracy= 0.6825396825396826
#               precision    recall  f1-score   support
#
#            0       0.69      0.82      0.75        66
#            1       0.00      0.00      0.00         7
#            2       0.68      0.60      0.64        53
#
#     accuracy                           0.68       126
#    macro avg       0.46      0.47      0.46       126
# weighted avg       0.65      0.68      0.66       126
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 200 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=200).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %% [markdown]
# LOGISTIC REGRESSION AFTER SCALING

# %%
model_lr=LogisticRegression(max_iter=200,random_state=46,C=0.1,penalty='l2',solver='lbfgs')
model_lr.fit(x_train_scaled,y_train)
y_pred_lr=model_lr.predict(x_test_scaled)
print('accuracy=',accuracy_score(y_test,y_pred_lr))
print(classification_report(y_test,y_pred_lr))
# Out:
# accuracy= 0.7698412698412699
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83        66
#            1       0.00      0.00      0.00         7
#            2       0.89      0.60      0.72        53
#
#     accuracy                           0.77       126
#    macro avg       0.54      0.53      0.52       126
# weighted avg       0.75      0.77      0.74       126
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %% [markdown]
# logistic regression with hypoparameters

# %%
param_grid={
'C':[0.01,0.1,1,10],
'penalty':['l2'],
'solver':['lbfgs','liblinear']
}
grid_lr=GridSearchCV(
    model_lr,
param_grid,
cv=5,
scoring='accuracy'
)

grid_lr.fit(x_train_scaled,y_train)
best_lr=grid_lr.best_estimator_
y_pred_lr=best_lr.predict(x_test_scaled)
print(grid_lr.best_params_)
y_pred_lr=model_lr.predict(x_test_scaled)
print('accuracy=',accuracy_score(y_test,y_pred_lr))
print(classification_report(y_test,y_pred_lr))
# Out:
# {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# accuracy= 0.7698412698412699
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83        66
#            1       0.00      0.00      0.00         7
#            2       0.89      0.60      0.72        53
#
#     accuracy                           0.77       126
#    macro avg       0.54      0.53      0.52       126
# weighted avg       0.75      0.77      0.74       126
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
cm = confusion_matrix(y_test, y_pred_lr)
print(cm)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)
plt.show()
# Out:
# [[65  0  1]
#  [ 4  0  3]
#  [21  0 32]]

# %%
best_lr=grid_lr.best_estimator_
scores = cross_val_score(
    best_lr,
    x,
    y,
    cv=5,
    scoring='accuracy'
)
print("Scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Scores: [0.76190476 0.78571429 0.67857143 0.69879518 0.68674699]
# Mean Accuracy: 0.722346528973035

# %% [markdown]
# KNN

# %%
model_knn=KNeighborsClassifier(n_neighbors=5,metric='manhattan',weights='distance')
model_knn.fit(x_train,y_train)
y_pred_knn=model_knn.predict(x_test)
print('accuracy=',accuracy_score(y_test,y_pred_knn))
print(classification_report(y_test,y_pred_knn))
# Out:
# accuracy= 0.7380952380952381
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.81        66
#            1       0.25      0.14      0.18         7
#            2       0.82      0.60      0.70        53
#
#     accuracy                           0.74       126
#    macro avg       0.60      0.55      0.56       126
# weighted avg       0.74      0.74      0.72       126

# %% [markdown]
# KNN AFTER SCALING

# %%
model_knn_S=KNeighborsClassifier(n_neighbors=5,metric='manhattan',weights='distance')
model_knn_S.fit(x_train_scaled,y_train)
y_pred_knn_S=model_knn_S.predict(x_test_scaled)
print('accuracy=',accuracy_score(y_test,y_pred_knn_S))
print(classification_report(y_test,y_pred_knn_S))
# Out:
# accuracy= 0.7222222222222222
#               precision    recall  f1-score   support
#
#            0       0.70      0.94      0.81        66
#            1       0.00      0.00      0.00         7
#            2       0.83      0.55      0.66        53
#
#     accuracy                           0.72       126
#    macro avg       0.51      0.50      0.49       126
# weighted avg       0.72      0.72      0.70       126

# %% [markdown]
# KNN HYPERPARAMETERS

# %%
from sklearn.neighbors import KNeighborsClassifier

param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

grid = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy'
)

grid.fit(x_train, y_train)
best_knn=grid.best_estimator_
y_pred_knn=best_knn.predict(x_test_scaled)
print(grid.best_params_)
print('accuracy=',accuracy_score(y_test,y_pred_knn))
print(classification_report(y_test,y_pred_knn))
# Out:
# {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# accuracy= 0.42063492063492064
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        66
#            1       0.00      0.00      0.00         7
#            2       0.42      1.00      0.59        53
#
#     accuracy                           0.42       126
#    macro avg       0.14      0.33      0.20       126
# weighted avg       0.18      0.42      0.25       126
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
cm = confusion_matrix(y_test, y_pred_knn)
print(cm)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)
plt.show()
# Out:
# [[ 0  0 66]
#  [ 0  0  7]
#  [ 0  0 53]]

# %%
best_knn = model_knn_S#grid.best_estimator_
scores = cross_val_score(
    best_knn,
    x,
    y,
    cv=5,
    scoring='accuracy'
)
print("Scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Scores: [0.66666667 0.58333333 0.58333333 0.60240964 0.71084337]
# Mean Accuracy: 0.6293172690763053

# %% [markdown]
# XG BOOST MODEL

# %%
from xgboost import XGBClassifier
model_xgb = XGBClassifier(random_state=46,subsample=0.5, n_estimators=100,max_depth=4,learning_rate=0.02,colsample_bytree=0.8)
model_xgb.fit(x_train, y_train)
y_pred_xgb = model_xgb.predict(x_test)
print('accuracy=',accuracy_score(y_test,y_pred_xgb))
print(classification_report(y_test,y_pred_xgb))
# Out:
# accuracy= 0.7936507936507936
#               precision    recall  f1-score   support
#
#            0       0.77      0.94      0.84        66
#            1       0.00      0.00      0.00         7
#            2       0.84      0.72      0.78        53
#
#     accuracy                           0.79       126
#    macro avg       0.54      0.55      0.54       126
# weighted avg       0.76      0.79      0.77       126
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %% [markdown]
# XGB WITH HPERPARAMETERS

# %%
param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1],
    'colsample_bytree': [0.8, 1]
}
grid_xgb_cv = GridSearchCV(
    XGBClassifier(random_state=46,subsample=0.5, n_estimators=100,max_depth=4,learning_rate=0.02,colsample_bytree=0.8
    ),
    param_grid,
    cv=5,
    scoring='accuracy'
)
grid_xgb_cv.fit(x_train, y_train)
best_xgb=grid_xgb_cv.best_estimator_
y_pred_xgb=best_xgb.predict(x_test)
print('accuracy=',accuracy_score(y_test,y_pred_xgb))
print(classification_report(y_test,y_pred_xgb))
# Out:
# accuracy= 0.7380952380952381
#               precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79        66
#            1       0.00      0.00      0.00         7
#            2       0.75      0.72      0.73        53
#
#     accuracy                           0.74       126
#    macro avg       0.50      0.52      0.51       126
# weighted avg       0.71      0.74      0.72       126

# %%
from sklearn.model_selection import RandomizedSearchCV
xgb = XGBClassifier(random_state=40,subsample=0.8, n_estimators=200,max_depth=3,learning_rate=0.01,colsample_bytree=1
)
random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_grid,
    n_iter=50,
    scoring='accuracy',
    cv=5,
    random_state=42,
    n_jobs=-1
)

random_search.fit(x_train, y_train)
best_xgb = random_search.best_estimator_
y_pred_xgb = best_xgb.predict (x_test)
print(random_search.best_params_)
print(random_search.best_score_)
print('accuracy=',accuracy_score(y_test,y_pred_xgb))
print(classification_report(y_test,y_pred_xgb))
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 48 is smaller than n_iter=50. Running 48 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# {'subsample': 0.8, 'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.8}
# 0.732729398012858
# accuracy= 0.7857142857142857
#               precision    recall  f1-score   support
#
#            0       0.75      0.94      0.83        66
#            1       0.00      0.00      0.00         7
#            2       0.86      0.70      0.77        53
#
#     accuracy                           0.79       126
#    macro avg       0.54      0.55      0.53       126
# weighted avg       0.75      0.79      0.76       126
# ...

# %%
cm = confusion_matrix(y_test, y_pred_xgb)
print(cm)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)
plt.show()
# Out:
# [[62  0  4]
#  [ 5  0  2]
#  [16  0 37]]

# %%
best_xgb=random_search.best_estimator_
scores = cross_val_score(
    best_xgb,
    x,
    y,
    cv=5,
    scoring='accuracy'
)
print("Scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Scores: [0.72619048 0.73809524 0.76190476 0.71084337 0.74698795]
# Mean Accuracy: 0.7368043602983362

# %% [markdown]
# GRAIDENT BOOSTIONG

# %%
gb = GradientBoostingClassifier(random_state=10,subsample=0.8,n_estimators=120,max_depth=3,learning_rate=0.01)
gb.fit(x_train, y_train)
y_pred_gb= gb.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred_gb))
print(classification_report(y_test, y_pred_gb))
# Out:
# Accuracy: 0.7936507936507936
#               precision    recall  f1-score   support
#
#            0       0.77      0.94      0.84        66
#            1       0.00      0.00      0.00         7
#            2       0.86      0.72      0.78        53
#
#     accuracy                           0.79       126
#    macro avg       0.54      0.55      0.54       126
# weighted avg       0.76      0.79      0.77       126

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(random_state=20,subsample=0.8,n_estimators=100,max_depth=3,learning_rate=0.01)

param_grid_gb = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5]
}

grid_gb = GridSearchCV(
    estimator=gb,
    param_grid=param_grid_gb,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid_gb.fit(x_train, y_train)
best_gb = grid_gb.best_estimator_
y_pred_gb=best_gb.predict(x_test)
print(grid_gb.best_params_)
print(grid_gb.best_score_)
print("Accuracy:", accuracy_score(y_test, best_gb.predict(x_test)))
print(classification_report(y_test, y_pred_gb))
# Out:
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}
# 0.729573348918761
# Accuracy: 0.7857142857142857
#               precision    recall  f1-score   support
#
#            0       0.77      0.94      0.84        66
#            1       0.00      0.00      0.00         7
#            2       0.86      0.70      0.77        53
#
#     accuracy                           0.79       126
#    macro avg       0.54      0.55      0.54       126
# weighted avg       0.76      0.79      0.77       126

# %%
cm = confusion_matrix(y_test, y_pred_gb)
print(cm)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)
plt.show()
# Out:
# [[62  1  3]
#  [ 4  0  3]
#  [15  1 37]]

# %%
scores = cross_val_score(
    best_gb,
    x,
    y,
    cv=5,
    scoring='accuracy'
)
print("Scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Scores: [0.72619048 0.77380952 0.72619048 0.69879518 0.74698795]
# Mean Accuracy: 0.7343947217441193

# %% [markdown]
# COMPARING ALL MODELS

# %%
'''
best_lr = grid_lr.best_estimator_
best_dt = grid_dt.best_estimator_
best_rf = grid_rf.best_estimator_
best_gb = grid_gb.best_estimator_
best_xgb = random_search.best_estimator_
'''
results = {
    "Logistic Regression": accuracy_score(y_test, best_lr.predict(x_test_scaled)),
    "Decision Tree": accuracy_score(y_test, best_dt.predict(x_test)),
    "Random Forest": accuracy_score(y_test, best_rf.predict(x_test)),
    "Gradient Boosting": accuracy_score(y_test,best_gb.predict(x_test)),
    "XGBoost": accuracy_score(y_test,best_xgb.predict(x_test))
}
comparison = pd.DataFrame(results.items(), columns=["Model", "Accuracy"])
comparison["Accuracy (%)"] = comparison["Accuracy"] * 100
comparison = comparison.sort_values(by="Accuracy", ascending=False)
print(comparison)
# Out:
#                  Model  Accuracy  Accuracy (%)
# 2        Random Forest  0.793651     79.365079
# 0  Logistic Regression  0.785714     78.571429
# 3    Gradient Boosting  0.785714     78.571429
# 4              XGBoost  0.785714     78.571429
# 1        Decision Tree  0.714286     71.428571

# %%
import joblib
import os
os.makedirs("models",exist_ok=True)
joblib.dump(best_rf, "cirrhosis_model_status.pkl")
print('saved succesfully')
# Out:
# saved succesfully

# %%
joblib.dump(le, "label_encoder.pkl")
# Out:
# ['label_encoder.pkl']

# %%
joblib.dump(best_xgb, "Random_forest_status.pkl")
# Out:
# ['Random_forest_status.pkl']
